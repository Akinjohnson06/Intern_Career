# %%
import pandas as pd

# %%
file = r"C:\Users\DELL\Desktop\youtubers_df.csv" #file path

# %%
youtuber = pd.read_csv(file)
youtuber.head()
# Out:
#    Rank       Username           Categories   Suscribers         Country  \
# 0     1        tseries       Música y baile  249500000.0           India
# 1     2        MrBeast   Videojuegos, Humor  183500000.0  Estados Unidos
# 2     3      CoComelon            Educación  165500000.0         Unknown
# 3     4       SETIndia                  NaN  162600000.0           India
# 4     5  KidsDianaShow  Animación, Juguetes  113500000.0         Unknown
#
#         Visits      Likes  Comments  \
# 0      86200.0     2700.0      78.0
# 1  117400000.0  5300000.0   18500.0
# 2    7000000.0    24700.0       0.0
# 3      15600.0      166.0       9.0
# 4    3900000.0    12400.0       0.0
#
#                                                Links
# 0  http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2  http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# 4  http://youtube.com/channel/UCk8GzjMOrta8yxDcKf...

# %%
# Data Exploration
# explore the dataset
youtuber.shape
# Out:
# (1000, 9)

# %%
youtuber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   int64
#  1   Username    1000 non-null   object
#  2   Categories  694 non-null    object
#  3   Suscribers  1000 non-null   float64
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   float64
#  6   Likes       1000 non-null   float64
#  7   Comments    1000 non-null   float64
#  8   Links       1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
youtuber.columns
# Out:
# Index(['Rank', 'Username', 'Categories', 'Suscribers', 'Country', 'Visits',
#        'Likes', 'Comments', 'Links'],
#       dtype='object')

# %%
youtuber.describe(include = 'all')
# Out:
#                Rank    Username      Categories    Suscribers         Country  \
# count   1000.000000        1000             694  1.000000e+03            1000
# unique          NaN         994              45           NaN              29
# top             NaN  NickyJamTV  Música y baile           NaN  Estados Unidos
# freq            NaN           2             160           NaN             293
# mean     500.500000         NaN             NaN  2.189440e+07             NaN
# std      288.819436         NaN             NaN  1.682775e+07             NaN
# min        1.000000         NaN             NaN  1.170000e+07             NaN
# 25%      250.750000         NaN             NaN  1.380000e+07             NaN
# 50%      500.500000         NaN             NaN  1.675000e+07             NaN
# 75%      750.250000         NaN             NaN  2.370000e+07             NaN
# max     1000.000000         NaN             NaN  2.495000e+08             NaN
#
#               Visits         Likes       Comments
# count   1.000000e+03  1.000000e+03    1000.000000
# unique           NaN           NaN            NaN
# top              NaN           NaN            NaN
# freq             NaN           NaN            NaN
# mean    1.209446e+06  5.363259e+04    1288.768000
# std     5.229942e+06  2.580457e+05    6778.188308
# min     0.000000e+00  0.000000e+00       0.000000
# 25%     3.197500e+04  4.717500e+02       2.000000
# 50%     1.744500e+05  3.500000e+03      67.000000
# 75%     8.654750e+05  2.865000e+04     472.000000
# max     1.174000e+08  5.300000e+06  154000.000000

# %%
# Clean data
# Dropping the link column
youtuber.drop(columns=['Links'], inplace = True) 
#inplace makes it permanent. Without it, it will just display what you want to see, and it will be temporary

# %%
youtuber.head()
# Out:
#    Rank       Username           Categories   Suscribers         Country  \
# 0     1        tseries       Música y baile  249500000.0           India
# 1     2        MrBeast   Videojuegos, Humor  183500000.0  Estados Unidos
# 2     3      CoComelon            Educación  165500000.0         Unknown
# 3     4       SETIndia                  NaN  162600000.0           India
# 4     5  KidsDianaShow  Animación, Juguetes  113500000.0         Unknown
#
#         Visits      Likes  Comments
# 0      86200.0     2700.0      78.0
# 1  117400000.0  5300000.0   18500.0
# 2    7000000.0    24700.0       0.0
# 3      15600.0      166.0       9.0
# 4    3900000.0    12400.0       0.0

# %%
# Renaming columns
youtuber.rename(columns = {'Username':'Youtube Names', 'Visits':'Streams', 'Suscribers':'Subscribers'}, inplace = True)

# %%
youtuber
# Out:
#      Rank         Youtube Names           Categories  Subscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country      Streams      Likes  Comments
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# 2           Unknown    7000000.0    24700.0       0.0
# 3             India      15600.0      166.0       9.0
# 4           Unknown    3900000.0    12400.0       0.0
# ..              ...          ...        ...       ...
# 995  Estados Unidos     397400.0    14000.0     124.0
# 996           India    1100000.0    92500.0     164.0
# 997         Unknown     211400.0      745.0       0.0
# 998           India      14000.0       81.0       1.0
# 999           India       2200.0       31.0       1.0
#
# [1000 rows x 8 columns]

# %%
youtuber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           1000 non-null   int64
#  1   Youtube Names  1000 non-null   object
#  2   Categories     694 non-null    object
#  3   Subscribers    1000 non-null   float64
#  4   Country        1000 non-null   object
#  5   Streams        1000 non-null   float64
#  6   Likes          1000 non-null   float64
#  7   Comments       1000 non-null   float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 62.6+ KB

# %%
youtuber
# Out:
#      Rank         Youtube Names           Categories  Subscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country      Streams      Likes  Comments
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# 2           Unknown    7000000.0    24700.0       0.0
# 3             India      15600.0      166.0       9.0
# 4           Unknown    3900000.0    12400.0       0.0
# ..              ...          ...        ...       ...
# 995  Estados Unidos     397400.0    14000.0     124.0
# 996           India    1100000.0    92500.0     164.0
# 997         Unknown     211400.0      745.0       0.0
# 998           India      14000.0       81.0       1.0
# 999           India       2200.0       31.0       1.0
#
# [1000 rows x 8 columns]

# %%
# Removing the decimal point in the Subcriber, streams, likes, and comments column
youtuber[['Subscribers', 'Streams', 'Likes', 'Comments']] = youtuber[['Subscribers', 'Streams', 'Likes', 'Comments']].astype(int)
youtuber.head()
# Out:
#    Rank  Youtube Names           Categories  Subscribers         Country  \
# 0     1        tseries       Música y baile    249500000           India
# 1     2        MrBeast   Videojuegos, Humor    183500000  Estados Unidos
# 2     3      CoComelon            Educación    165500000         Unknown
# 3     4       SETIndia                  NaN    162600000           India
# 4     5  KidsDianaShow  Animación, Juguetes    113500000         Unknown
#
#      Streams    Likes  Comments
# 0      86200     2700        78
# 1  117400000  5300000     18500
# 2    7000000    24700         0
# 3      15600      166         9
# 4    3900000    12400         0

# %%
# check for null values
#youtuber.isnull()
youtuber.isnull().sum()
# Out:
# Rank               0
# Youtube Names      0
# Categories       306
# Subscribers        0
# Country            0
# Streams            0
# Likes              0
# Comments           0
# dtype: int64

# %%
# dealing with missing value
# we can input it into another variable, just so that we dont tamper with the original Dataframe
youtubers = youtuber.fillna(value = 'None')
youtubers
# Out:
#      Rank         Youtube Names           Categories  Subscribers  \
# 0       1               tseries       Música y baile    249500000
# 1       2               MrBeast   Videojuegos, Humor    183500000
# 2       3             CoComelon            Educación    165500000
# 3       4              SETIndia                 None    162600000
# 4       5         KidsDianaShow  Animación, Juguetes    113500000
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                 None     11700000
# 996   997            Adaahqueen                 None     11700000
# 997   998  LittleAngelIndonesia       Música y baile     11700000
# 998   999          PenMultiplex                 None     11700000
# 999  1000         OneindiaHindi  Noticias y Política     11700000
#
#             Country    Streams    Likes  Comments
# 0             India      86200     2700        78
# 1    Estados Unidos  117400000  5300000     18500
# 2           Unknown    7000000    24700         0
# 3             India      15600      166         9
# 4           Unknown    3900000    12400         0
# ..              ...        ...      ...       ...
# 995  Estados Unidos     397400    14000       124
# 996           India    1100000    92500       164
# 997         Unknown     211400      745         0
# 998           India      14000       81         1
# 999           India       2200       31         1
#
# [1000 rows x 8 columns]

# %%
# Check if it worked
youtubers.isnull().sum()
# Out:
# Rank             0
# Youtube Names    0
# Categories       0
# Subscribers      0
# Country          0
# Streams          0
# Likes            0
# Comments         0
# dtype: int64

# %%
youtubers.head(20)
# Out:
#     Rank         Youtube Names              Categories  Subscribers  \
# 0      1               tseries          Música y baile    249500000
# 1      2               MrBeast      Videojuegos, Humor    183500000
# 2      3             CoComelon               Educación    165500000
# 3      4              SETIndia                    None    162600000
# 4      5         KidsDianaShow     Animación, Juguetes    113500000
# 5      6             PewDiePie  Películas, Videojuegos    111500000
# 6      7    LikeNastyaofficial                Juguetes    107500000
# 7      8           VladandNiki     Animación, Juguetes    101400000
# 8      9       zeemusiccompany          Música y baile     99700000
# 9     10                   WWE             Videojuegos     97200000
# 10    11             BLACKPINK          Música y baile     91300000
# 11    12    GoldminesTelefilms                    None     89700000
# 12    13               SonySAB    Películas, Animación     85400000
# 13    14  5MinuteCraftsYouTube               Películas     80300000
# 14    15                   BTS          Música y baile     76500000
# 15    16            HYBELABELS          Música y baile     72700000
# 16    17                 zeetv                    None     72500000
# 17    18              Pinkfong     Animación, Juguetes     69600000
# 18    19              ChuChuTV                Juguetes     67500000
# 19    20             KondZilla          Música y baile     66599999
#
#            Country    Streams    Likes  Comments
# 0            India      86200     2700        78
# 1   Estados Unidos  117400000  5300000     18500
# 2          Unknown    7000000    24700         0
# 3            India      15600      166         9
# 4          Unknown    3900000    12400         0
# 5   Estados Unidos    2400000   197300      4900
# 6          Unknown    2600000    28000         0
# 7          Unknown    4100000    22100         0
# 8            India      74300     2600        32
# 9   Estados Unidos     184500     6300       214
# 10  Estados Unidos     863200   146900      3400
# 11           India      34600      421        13
# 12           India      35500      615        21
# 13           India     164600      703        35
# 14           India     969700   180300      7400
# 15  Estados Unidos     440700    23900       932
# 16           India       7300      144         1
# 17         Unknown     506400      397         0
# 18         Unknown     652100    17800         0
# 19          Brasil      30400     1100         4

# %%
# Trends amongst the top streamers
# which categories are the most popular
x = youtubers.sort_values('Streams', ascending = False)#.head(10)
x[['Categories', 'Streams']].head(10)
# Out:
#              Categories    Streams
# 1    Videojuegos, Humor  117400000
# 136       Vlogs diarios   83100000
# 153    Animación, Humor   52700000
# 488     Comida y bebida   21500000
# 288                None   21500000
# 390                None   19100000
# 586                None   15400000
# 958      Música y baile   13600000
# 300                None   12900000
# 805            Deportes   12200000

# %%
# correlation between the number of subscribers and the number of likes or comments
youtubers['Subscribers'].corr(youtubers['Likes'])
# the result shows that they are a little bit correlated based on the correlation range of -1 to 1
# Out:
# 0.21163868364873334

# %%
# distribution of streamer audiences by country.
x = youtubers.sort_values('Streams', ascending = False)
x[['Country', 'Streams']].head(10)
# Out:
#             Country    Streams
# 1    Estados Unidos  117400000
# 136  Estados Unidos   83100000
# 153  Estados Unidos   52700000
# 488  Estados Unidos   21500000
# 288           India   21500000
# 390           India   19100000
# 586  Estados Unidos   15400000
# 958  Estados Unidos   13600000
# 300     El Salvador   12900000
# 805  Estados Unidos   12200000

# %%
youtubers
# Out:
#      Rank         Youtube Names           Categories  Subscribers  \
# 0       1               tseries       Música y baile    249500000
# 1       2               MrBeast   Videojuegos, Humor    183500000
# 2       3             CoComelon            Educación    165500000
# 3       4              SETIndia                 None    162600000
# 4       5         KidsDianaShow  Animación, Juguetes    113500000
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                 None     11700000
# 996   997            Adaahqueen                 None     11700000
# 997   998  LittleAngelIndonesia       Música y baile     11700000
# 998   999          PenMultiplex                 None     11700000
# 999  1000         OneindiaHindi  Noticias y Política     11700000
#
#             Country    Streams    Likes  Comments
# 0             India      86200     2700        78
# 1    Estados Unidos  117400000  5300000     18500
# 2           Unknown    7000000    24700         0
# 3             India      15600      166         9
# 4           Unknown    3900000    12400         0
# ..              ...        ...      ...       ...
# 995  Estados Unidos     397400    14000       124
# 996           India    1100000    92500       164
# 997         Unknown     211400      745         0
# 998           India      14000       81         1
# 999           India       2200       31         1
#
# [1000 rows x 8 columns]

# %%
# average number of subscribers, visits, likes, and comments.
x = youtubers ['Subscribers'].mean()
y = youtubers ['Streams'].mean()
z = youtubers ['Likes'].mean()
zz = youtubers ['Comments'].mean()

print(f'average subscriber is {x}')
print(f'average stream is {y}')
print(f'average likes is {z}')
print(f'average comments is {zz}')
# Out:
# average subscriber is 21894399.987
# average stream is 1209446.315
# average likes is 53632.592
# average comments is 1288.768

# %%
# categories have the highest number of streamers
youtubers[['Categories', 'Streams']].sort_values('Streams', ascending = False).head(10)
#youtubers[['Categories', 'Streams']].head(10)
# Out:
#              Categories    Streams
# 1    Videojuegos, Humor  117400000
# 136       Vlogs diarios   83100000
# 153    Animación, Humor   52700000
# 488     Comida y bebida   21500000
# 288                None   21500000
# 390                None   19100000
# 586                None   15400000
# 958      Música y baile   13600000
# 300                None   12900000
# 805            Deportes   12200000
